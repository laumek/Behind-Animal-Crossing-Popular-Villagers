# %%
import requests, os, pickle
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime


url = "https://nookipedia.com/wiki/Villager/New_Horizons"
response = requests.get(url)
if response.status_code != 200:
    raise Exception(f"Failed to load page with status code: {response.status_code}")

soup = BeautifulSoup(response.content, 'html.parser')

# %%
table = soup.find('table')
rows = table.find_all('tr', {"style" : "text-align:center;"})

characters = []

os.makedirs("villager_images", exist_ok=True)

for r in rows:
  
  img_tag = r.find('img')
  if img_tag:
    # Extract image URL (src) and image description (alt)
    img_url = img_tag['src'] if 'src' in img_tag.attrs else None
    img_alt = img_tag['alt'] if 'alt' in img_tag.attrs else None

    if img_url:
      img_response = requests.get(img_url)
      if img_response.status_code == 200:
        img_filename = f'villager_images/{img_alt}'
        with open(img_filename, 'wb') as img_file:
          img_file.write(img_response.content)

        characters.append({'Name': img_alt, 'Image path': img_filename})

# %%
images_df = pd.DataFrame(characters)

# %%
images_df['Name'] = images_df['Name'].str.split("'s").str[0]

# %%
re = images_df.loc[images_df['Name'].str.contains('Wart')]

HTML(re.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Image path</th>
#       <th>Image</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>402</th>
#       <td>Wart Jr.</td>
#       <td>villager_images/Wart Jr.'s Photo NH Texture.png</td>
#       <td><img src="villager_images/Wart Jr.'s Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#   </tbody>
# </table>

# %%
from IPython.display import HTML

def path_to_image_html(path):
    return f'<img src="{path}" width="50" height="50">'

images_df['Image'] = images_df['Image path'].apply(path_to_image_html)

HTML(images_df.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Name</th>
#       <th>Image path</th>
#       <th>Image</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Ace</td>
#       <td>villager_images/Ace's Photo NH Texture.png</td>
#       <td><img src="villager_images/Ace's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Admiral</td>
#       <td>villager_images/Admiral's Photo NH Texture.png</td>
#       <td><img src="villager_images/Admiral's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Agent S</td>
#       <td>villager_images/Agent S's Photo NH Texture.png</td>
#       <td><img src="villager_images/Agent S's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Agnes</td>
#       <td>villager_images/Agnes's Photo NH Texture.png</td>
#       <td><img src="villager_images/Agnes's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Al</td>
#       <td>villager_images/Al's Photo NH Texture.png</td>
#       <td><img src="villager_images/Al's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Alfonso</td>
#       <td>villager_images/Alfonso's Photo NH Texture.png</td>
#       <td><img src="villager_images/Alfonso's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Alice</td>
#       <td>villager_images/Alice's Photo NH Texture.png</td>
#       <td><img src="villager_images/Alice's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Alli</td>
#       <td>villager_images/Alli's Photo NH Texture.png</td>
#       <td><img src="villager_images/Alli's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Amelia</td>
#       <td>villager_images/Amelia's Photo NH Texture.png</td>
#       <td><img src="villager_images/Amelia's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Anabelle</td>
#       <td>villager_images/Anabelle's Photo NH Texture.png</td>
#       <td><img src="villager_images/Anabelle's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Anchovy</td>
#       <td>villager_images/Anchovy's Photo NH Texture.png</td>
#       <td><img src="villager_images/Anchovy's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Angus</td>
#       <td>villager_images/Angus's Photo NH Texture.png</td>
#       <td><img src="villager_images/Angus's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Anicotti</td>
#       <td>villager_images/Anicotti's Photo NH Texture.png</td>
#       <td><img src="villager_images/Anicotti's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Ankha</td>
#       <td>villager_images/Ankha's Photo NH Texture.png</td>
#       <td><img src="villager_images/Ankha's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Annalisa</td>
#       <td>villager_images/Annalisa's Photo NH Texture.png</td>
#       <td><img src="villager_images/Annalisa's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Annalise</td>
#       <td>villager_images/Annalise's Photo NH Texture.png</td>
#       <td><img src="villager_images/Annalise's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Antonio</td>
#       <td>villager_images/Antonio's Photo NH Texture.png</td>
#       <td><img src="villager_images/Antonio's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Apollo</td>
#       <td>villager_images/Apollo's Photo NH Texture.png</td>
#       <td><img src="villager_images/Apollo's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Apple</td>
#       <td>villager_images/Apple's Photo NH Texture.png</td>
#       <td><img src="villager_images/Apple's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Astrid</td>
#       <td>villager_images/Astrid's Photo NH Texture.png</td>
#       <td><img src="villager_images/Astrid's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Audie</td>
#       <td>villager_images/Audie's Photo NH Texture.png</td>
#       <td><img src="villager_images/Audie's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Aurora</td>
#       <td>villager_images/Aurora's Photo NH Texture.png</td>
#       <td><img src="villager_images/Aurora's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Ava</td>
#       <td>villager_images/Ava's Photo NH Texture.png</td>
#       <td><img src="villager_images/Ava's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>Avery</td>
#       <td>villager_images/Avery's Photo NH Texture.png</td>
#       <td><img src="villager_images/Avery's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>Axel</td>
#       <td>villager_images/Axel's Photo NH Texture.png</td>
#       <td><img src="villager_images/Axel's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>Azalea</td>
#       <td>villager_images/Azalea's Photo NH Texture.png</td>
#       <td><img src="villager_images/Azalea's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>Baabara</td>
#       <td>villager_images/Baabara's Photo NH Texture.png</td>
#       <td><img src="villager_images/Baabara's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>Bam</td>
#       <td>villager_images/Bam's Photo NH Texture.png</td>
#       <td><img src="villager_images/Bam's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>Bangle</td>
#       <td>villager_images/Bangle's Photo NH Texture.png</td>
#       <td><img src="villager_images/Bangle's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>Barold</td>
#       <td>villager_images/Barold's Photo NH Texture.png</td>
#       <td><img src="villager_images/Barold's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>Bea</td>
#       <td>villager_images/Bea's Photo NH Texture.png</td>
#       <td><img src="villager_images/Bea's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>Beardo</td>
#       <td>villager_images/Beardo's Photo NH Texture.png</td>
#       <td><img src="villager_images/Beardo's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>Beau</td>
#       <td>villager_images/Beau's Photo NH Texture.png</td>
#       <td><img src="villager_images/Beau's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>Becky</td>
#       <td>villager_images/Becky's Photo NH Texture.png</td>
#       <td><img src="villager_images/Becky's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>Bella</td>
#       <td>villager_images/Bella's Photo NH Texture.png</td>
#       <td><img src="villager_images/Bella's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>Benedict</td>
#       <td>villager_images/Benedict's Photo NH Texture.png</td>
#       <td><img src="villager_images/Benedict's Photo NH Texture.png" width="50" height="50"></td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>Benjamin</td>
#       <td>villager_images/Benja

# %%
images_df.to_pickle("images_df.pkl")

# %%
# Save the DataFrame with image tags as an HTML file
images_df.to_html('villagers_with_images.html', escape=False)
